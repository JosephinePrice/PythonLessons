# %%
import pandas as pd
import requests
import matplotlib.pyplot as plt

# %%
# you can rename any library as you import it
import math as m

m.ceil(8.4)
# Out:
# 9

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is CCEB-C2E4
#
#  Directory of C:\Users\Winadmin
#
# 10/09/2021  10:28    <DIR>          .
# 10/09/2021  10:28    <DIR>          ..
# 10/09/2021  09:38               306 .bash_history
# 26/08/2021  09:03    <DIR>          .conda
# 25/08/2021  12:46                25 .condarc
# 25/08/2021  12:43    <DIR>          .continuum
# 18/08/2021  12:43               186 .gitconfig
# 10/09/2021  09:33    <DIR>          .ipynb_checkpoints
# 14/07/2021  14:05    <DIR>          .ipython
# 21/07/2021  14:47    <DIR>          .jupyter
# 01/09/2021  14:59            29,760 1 Sept Scraper HW.ipynb
# 20/08/2020  15:32    <DIR>          3D Objects
# 14/07/2021  13:06    <DIR>          anaconda3
# 18/08/2021  14:57            14,197 Classes Homework .ipynb
# 20/08/2020  15:32    <DIR>          Contacts
# 06/08/2021  10:05             3,813 Define functions .ipynb
# 10/09/2021  09:35    <DIR>          Desktop
# ...

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is CCEB-C2E4
#
#  Directory of C:\Users\Winadmin
#
# 10/09/2021  10:34    <DIR>          .
# 10/09/2021  10:34    <DIR>          ..
# 10/09/2021  09:38               306 .bash_history
# 26/08/2021  09:03    <DIR>          .conda
# 25/08/2021  12:46                25 .condarc
# 25/08/2021  12:43    <DIR>          .continuum
# 18/08/2021  12:43               186 .gitconfig
# 10/09/2021  09:33    <DIR>          .ipynb_checkpoints
# 14/07/2021  14:05    <DIR>          .ipython
# 21/07/2021  14:47    <DIR>          .jupyter
# 01/09/2021  14:59            29,760 1 Sept Scraper HW.ipynb
# 20/08/2020  15:32    <DIR>          3D Objects
# 14/07/2021  13:06    <DIR>          anaconda3
# 18/08/2021  14:57            14,197 Classes Homework .ipynb
# 20/08/2020  15:32    <DIR>          Contacts
# 06/08/2021  10:05             3,813 Define functions .ipynb
# 10/09/2021  10:34    <DIR>          Desktop
# ...

# %%
df = pd.read_csv('malang_khostay')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e8389f385ed7> in <module>
# ----> 1 df = pd.read_csv('malang_khostay')
#
# NameError: name 'pd' is not defined

# %%
pd.options.display.max_columns = 60
df.head()
# Out:
#                     id      conversation_id               created_at  \
# 0  1435793001192824836  1435793001192824836  2021-09-09 03:31:41 BST
# 1  1435792487382196224  1435789168060375042  2021-09-09 03:29:39 BST
# 2  1435792423444271108  1435789168060375042  2021-09-09 03:29:24 BST
# 3  1435789168060375042  1435789168060375042  2021-09-09 03:16:27 BST
# 4  1435788970340855809  1435788970340855809  2021-09-09 03:15:40 BST
#
#          date      time  timezone              user_id       username    name  \
# 0  2021-09-09  03:31:41       100  1413229327068581889  malangkhostay  Malang
# 1  2021-09-09  03:29:39       100  1413229327068581889  malangkhostay  Malang
# 2  2021-09-09  03:29:24       100  1413229327068581889  malangkhostay  Malang
# 3  2021-09-09  03:16:27       100  1413229327068581889  malangkhostay  Malang
# 4  2021-09-09  03:15:40       100  1413229327068581889  malangkhostay  Malang
#
#    place                                              tweet language mentions  \
# ...

# %%
df.photos
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-187733cc565e> in <module>
# ----> 1 df.photos
#
# NameError: name 'df' is not defined

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.photos
# Out:
# 0      ['https://pbs.twimg.com/media/E-z2IB4XEAoLNuH....
# 1                                                     []
# 2                                                     []
# 3      ['https://pbs.twimg.com/media/E-zyozuWYAAScCU....
# 4      ['https://pbs.twimg.com/media/E-zydYuXMAELfbl....
#                              ...
# 524    ['https://pbs.twimg.com/media/E-McFKcVQAQGJxy....
# 525                                                   []
# 526                                                   []
# 527                                                   []
# 528                                                   []
# Name: photos, Length: 529, dtype: object

# %%
df['photos']
# Out:
# 0      ['https://pbs.twimg.com/media/E-z2IB4XEAoLNuH....
# 1                                                     []
# 2                                                     []
# 3      ['https://pbs.twimg.com/media/E-zyozuWYAAScCU....
# 4      ['https://pbs.twimg.com/media/E-zydYuXMAELfbl....
#                              ...
# 524    ['https://pbs.twimg.com/media/E-McFKcVQAQGJxy....
# 525                                                   []
# 526                                                   []
# 527                                                   []
# 528                                                   []
# Name: photos, Length: 529, dtype: object

# %%
df.photos.loc[524]
# Out:
# "['https://pbs.twimg.com/media/E-McFKcVQAQGJxy.jpg', 'https://pbs.twimg.com/media/E-McF_zUcAYujCN.jpg', 'https://pbs.twimg.com/media/E-McGu-VUAIRUGo.jpg', 'https://pbs.twimg.com/media/E-McHalVQAkHIwT.jpg']"

# %%
# desired output

['url1', 'url2']
# Out:
# ['url1', 'url2']

# %%
urls = []
for x in df.photos:
    urls.append(x)

# %%
urls
# Out:
# ["['https://pbs.twimg.com/media/E-z2IB4XEAoLNuH.jpg']",
#  '[]',
#  '[]',
#  "['https://pbs.twimg.com/media/E-zyozuWYAAScCU.jpg']",
#  "['https://pbs.twimg.com/media/E-zydYuXMAELfbl.jpg']",
#  "['https://pbs.twimg.com/tweet_video_thumb/E-ztIvnXEAINBM7.jpg']",
#  "['https://pbs.twimg.com/media/E-zo6E1WYAAwCae.jpg']",
#  '[]',
#  "['https://pbs.twimg.com/media/E-y5c2wXsA0heBU.jpg']",
#  "['https://pbs.twimg.com/media/E-yw3w0XsAUhePr.jpg']",
#  "['https://pbs.twimg.com/media/E-yaLMxXsAU1NyV.jpg']",
#  '[]',
#  '[]',
#  '[]',
#  "['https://pbs.twimg.com/media/E-yB1w4UcAA3znj.jpg', 'https://pbs.twimg.com/media/E-yB25PVUAYYssK.jpg', 'https://pbs.twimg.com/media/E-yB39_VEAYOVan.jpg', 'https://pbs.twimg.com/media/E-yB48iUYAMSKID.jpg']",
#  "['https://pbs.twimg.com/media/E-yAtvCVIAMtKtC.jpg']",
#  '[]',
#  '[]',
#  "['https://pbs.twimg.com/media/E-xkQngWUAI9-C2.jpg']",
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  "['https://pbs.twimg.com/media/E-wtpfkWYAYDBtX.jpg']",
# ...

# %%
urls = list(df.photos.values)

# %%
df.photos.values
# Out:
# array(["['https://pbs.twimg.com/media/E-z2IB4XEAoLNuH.jpg']", '[]', '[]',
#        "['https://pbs.twimg.com/media/E-zyozuWYAAScCU.jpg']",
#        "['https://pbs.twimg.com/media/E-zydYuXMAELfbl.jpg']",
#        "['https://pbs.twimg.com/tweet_video_thumb/E-ztIvnXEAINBM7.jpg']",
#        "['https://pbs.twimg.com/media/E-zo6E1WYAAwCae.jpg']", '[]',
#        "['https://pbs.twimg.com/media/E-y5c2wXsA0heBU.jpg']",
#        "['https://pbs.twimg.com/media/E-yw3w0XsAUhePr.jpg']",
#        "['https://pbs.twimg.com/media/E-yaLMxXsAU1NyV.jpg']", '[]', '[]',
#        '[]',
#        "['https://pbs.twimg.com/media/E-yB1w4UcAA3znj.jpg', 'https://pbs.twimg.com/media/E-yB25PVUAYYssK.jpg', 'https://pbs.twimg.com/media/E-yB39_VEAYOVan.jpg', 'https://pbs.twimg.com/media/E-yB48iUYAMSKID.jpg']",
#        "['https://pbs.twimg.com/media/E-yAtvCVIAMtKtC.jpg']", '[]', '[]',
#        "['https://pbs.twimg.com/media/E-xkQngWUAI9-C2.jpg']", '[]', '[]',
#        '[]', '[]', '[]', '[]',
# ...

# %%
urls[0]
# want this to equal just this bit 'https://pbs.twimg.com/media/E-z2IB4XEAoLNuH.jpg'
# Out:
# "['https://pbs.twimg.com/media/E-z2IB4XEAoLNuH.jpg']"

# %%
"Josie".replace('e', 'i')
# Out:
# 'Josii'

# %%
urls[0].replace('[', '').replace(']', '')
# Out:
# "'https://pbs.twimg.com/media/E-z2IB4XEAoLNuH.jpg'"

# %%
urls[0].replace('[', '').replace(']', '').replace("'", "")
# Out:
# 'https://pbs.twimg.com/media/E-z2IB4XEAoLNuH.jpg'

# %%
x = urls[0].replace('[', '').replace(']', '')

# %%
new_urls = []
for x in urls:
    # do some stuff
    x = x.replace('[', '').replace(']', '').replace("'", "")
    new_urls.append(x)

# %%
if '':
    print(1)
else:
    print(0)
if 'hi':
    print(1)
else:
    print(0)
# Out:
# 0
# 1

# %%
# if you have a list that contains blank strings
# this is a useful code snippet to remove them

new_urls = [x for x in new_urls if x]
new_urls
# Out:
# ['https://pbs.twimg.com/media/E-z2IB4XEAoLNuH.jpg',
#  'https://pbs.twimg.com/media/E-zyozuWYAAScCU.jpg',
#  'https://pbs.twimg.com/media/E-zydYuXMAELfbl.jpg',
#  'https://pbs.twimg.com/tweet_video_thumb/E-ztIvnXEAINBM7.jpg',
#  'https://pbs.twimg.com/media/E-zo6E1WYAAwCae.jpg',
#  'https://pbs.twimg.com/media/E-y5c2wXsA0heBU.jpg',
#  'https://pbs.twimg.com/media/E-yw3w0XsAUhePr.jpg',
#  'https://pbs.twimg.com/media/E-yaLMxXsAU1NyV.jpg',
#  'https://pbs.twimg.com/media/E-yB1w4UcAA3znj.jpg, https://pbs.twimg.com/media/E-yB25PVUAYYssK.jpg, https://pbs.twimg.com/media/E-yB39_VEAYOVan.jpg, https://pbs.twimg.com/media/E-yB48iUYAMSKID.jpg',
#  'https://pbs.twimg.com/media/E-yAtvCVIAMtKtC.jpg',
#  'https://pbs.twimg.com/media/E-xkQngWUAI9-C2.jpg',
#  'https://pbs.twimg.com/media/E-wtpfkWYAYDBtX.jpg',
#  'https://pbs.twimg.com/media/E-wkMCmWEAMyYqn.jpg',
#  'https://pbs.twimg.com/media/E-wd5NBVIAkZzZ0.jpg',
#  'https://pbs.twimg.com/media/E-wZg_CWQAIcbO8.jpg',
# ...

# %%
new_urls[8].split(',')
# Out:
# ['https://pbs.twimg.com/media/E-yB1w4UcAA3znj.jpg',
#  ' https://pbs.twimg.com/media/E-yB25PVUAYYssK.jpg',
#  ' https://pbs.twimg.com/media/E-yB39_VEAYOVan.jpg',
#  ' https://pbs.twimg.com/media/E-yB48iUYAMSKID.jpg']

# %%
[x.lstrip() for x in new_urls[8].split(',')]
# Out:
# ['https://pbs.twimg.com/media/E-yB1w4UcAA3znj.jpg',
#  'https://pbs.twimg.com/media/E-yB25PVUAYYssK.jpg',
#  'https://pbs.twimg.com/media/E-yB39_VEAYOVan.jpg',
#  'https://pbs.twimg.com/media/E-yB48iUYAMSKID.jpg']

# %%
'     hello'.lstrip()
# Out:
# 'hello'

# %%
len('abc')
# Out:
# 3

# %%
len([1,2,3,4])
# Out:
# 4

# %%
final_urls = []
for x in new_urls:
    if len(x.split(',')) > 1:
        new_strings = [x.lstrip() for x in new_urls[8].split(',')]
        for item in new_strings:
            final_urls.append(item)
    else:
        final_urls.append(x)
final_urls
# Out:
# ['https://pbs.twimg.com/media/E-z2IB4XEAoLNuH.jpg',
#  'https://pbs.twimg.com/media/E-zyozuWYAAScCU.jpg',
#  'https://pbs.twimg.com/media/E-zydYuXMAELfbl.jpg',
#  'https://pbs.twimg.com/tweet_video_thumb/E-ztIvnXEAINBM7.jpg',
#  'https://pbs.twimg.com/media/E-zo6E1WYAAwCae.jpg',
#  'https://pbs.twimg.com/media/E-y5c2wXsA0heBU.jpg',
#  'https://pbs.twimg.com/media/E-yw3w0XsAUhePr.jpg',
#  'https://pbs.twimg.com/media/E-yaLMxXsAU1NyV.jpg',
#  'https://pbs.twimg.com/media/E-yB1w4UcAA3znj.jpg',
#  'https://pbs.twimg.com/media/E-yB25PVUAYYssK.jpg',
#  'https://pbs.twimg.com/media/E-yB39_VEAYOVan.jpg',
#  'https://pbs.twimg.com/media/E-yB48iUYAMSKID.jpg',
#  'https://pbs.twimg.com/media/E-yAtvCVIAMtKtC.jpg',
#  'https://pbs.twimg.com/media/E-xkQngWUAI9-C2.jpg',
#  'https://pbs.twimg.com/media/E-wtpfkWYAYDBtX.jpg',
#  'https://pbs.twimg.com/media/E-wkMCmWEAMyYqn.jpg',
#  'https://pbs.twimg.com/media/E-wd5NBVIAkZzZ0.jpg',
#  'https://pbs.twimg.com/media/E-wZg_CWQAIcbO8.jpg',
# ...

# %%
for count, x in enumerate(['a', 'b', 'c']):
    print(count, x)
# Out:
# 0 a
# 1 b
# 2 c

# %%
for count, url in enumerate(final_urls):

    response = requests.get(url)
    if response.status_code == 200:
        with open("C:\\Users\\Winadmin\\Desktop\\taliban_images\\{}.jpg".format(count + 1), 'wb') as f:
            f.write(response.content)
    else:
        print("Error: {}".format(response.status_code))
        print("This happend for url: {}".format(url))

# %%
df.date = pd.to_datetime(df.date)

# %%
 df.loc[df.date > '2021-09-04']
# Out:
#                       id      conversation_id          created_at       date  \
# 0    1435793001192824836  1435793001192824836 2021-09-09 03:31:41 2021-09-09
# 1    1435792487382196224  1435789168060375042 2021-09-09 03:29:39 2021-09-09
# 2    1435792423444271108  1435789168060375042 2021-09-09 03:29:24 2021-09-09
# 3    1435789168060375042  1435789168060375042 2021-09-09 03:16:27 2021-09-09
# 4    1435788970340855809  1435788970340855809 2021-09-09 03:15:40 2021-09-09
# ..                   ...                  ...                 ...        ...
# 197  1434417536867749894  1434402171009777665 2021-09-05 08:26:05 2021-09-05
# 198  1434416733717213187  1434416733717213187 2021-09-05 08:22:54 2021-09-05
# 199  1434304226994360320  1434302318812483584 2021-09-05 00:55:50 2021-09-05
# 200  1434302318812483584  1434302318812483584 2021-09-05 00:48:15 2021-09-05
# 201  1434290409916751875  1434290409916751875 2021-09-05 00:00:56 2021-09-05
#
# ...

# %%
df = pd.read_csv("https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv")

# %%
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df.tail(10)
# Out:
#         crim   zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 496  0.28960  0.0   9.69     0  0.585  5.390  72.9  2.7986    6  391     19.2
# 497  0.26838  0.0   9.69     0  0.585  5.794  70.6  2.8927    6  391     19.2
# 498  0.23912  0.0   9.69     0  0.585  6.019  65.3  2.4091    6  391     19.2
# 499  0.17783  0.0   9.69     0  0.585  5.569  73.5  2.3999    6  391     19.2
# 500  0.22438  0.0   9.69     0  0.585  6.027  79.7  2.4982    6  391     19.2
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#           b  lstat  medv
# 496  396.90  21.14  19.7
# 497  396.90  14.10  18.3
# 498  396.90  12.92  21.2
# ...

# %%
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
df.dtypes
# Out:
# crim       float64
# zn         float64
# indus      float64
# chas         int64
# nox        float64
# rm         float64
# age        float64
# dis        float64
# rad          int64
# tax          int64
# ptratio    float64
# b          float64
# lstat      float64
# medv       float64
# dtype: object

# %%
df.crim.plot();

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is CCEB-C2E4
#
#  Directory of C:\Users\Winadmin\Desktop\PYTHON LESSONS
#
# 15/09/2021  14:46    <DIR>          .
# 15/09/2021  14:46    <DIR>          ..
# 15/09/2021  14:26    <DIR>          .ipynb_checkpoints
# 13/08/2021  10:10             3,569 For Loops Homework.ipynb
# 07/07/2021  14:02             5,687 functions practice.ipynb
# 15/09/2021  14:40            12,600 Malang YT data.xlsx
# 10/08/2021  15:07             6,039 NV Lesson - Class, functions .ipynb
# 15/09/2021  14:44           202,195 Pandas.ipynb
# 07/07/2021  13:39            47,130 Prediction Interval Methodology for Linear Regression.ipynb
# 11/08/2021  15:30            11,307 Python 11th August Practice.ipynb
# 06/08/2021  13:17            10,303 python_practice Josie.ipynb
# 26/08/2021  13:58             2,849 Scraper Example.ipynb
# 31/08/2021  17:06            26,784 Scraper Homework + Lesson (27 Aug)-Copy1.ipynb
# ...

# %%
# This is actually irrelevant here since anaconda has already installed opnepyxl
# But this code snippet is fairly useful to remember - it's how you install a new python package if it's not in anaconda

import sys
# !{sys.executable} -m pip install openpyxl

# %%
df = pd.read_excel("Malang YT data.xlsx")

# %%
df.head()
# Out:
#                                         Video Titles Descriptions  \
# 0  Taliban at Georgopol PUBG.  49 containers full...      NO DATA
# 1  Taliban caught 6.5 Million dollars in Amrullah...      NO DATA
# 2  Womens protest in Nangrahar for the support of...      NO DATA
# 3  Qatar Foreign Minister meet with IEA Leaders a...      NO DATA
# 4                                 IEA Military force      NO DATA
#
#                                    Thumbnail URLs  \
# 0  https://i.ytimg.com/vi/WCJA3SoayCc/default.jpg
# 1  https://i.ytimg.com/vi/k96gBGUbzzk/default.jpg
# 2  https://i.ytimg.com/vi/wNypwm7aaQc/default.jpg
# 3  https://i.ytimg.com/vi/Yt42vB98wAI/default.jpg
# 4  https://i.ytimg.com/vi/nggrzPl3ePQ/default.jpg
#
#                                     Video URLs Publish Times in ISO-8601  \
# 0  https://www.youtube.com/watch?v=WCJA3SoayCc      2021-09-15T10:46:49Z
# 1  https://www.youtube.com/watch?v=k96gBGUbzzk      2021-09-13T08:43:47Z
# ...

# %%
df.columns
# Out:
# Index(['Video Titles', 'Descriptions', 'Thumbnail URLs', 'Video URLs',
#        'Publish Times in ISO-8601', 'Channel URL'],
#       dtype='object')

# %%
df["Publish Times in ISO-8601"]
# Out:
# 0     2021-09-15T10:46:49Z
# 1     2021-09-13T08:43:47Z
# 2     2021-09-12T18:04:40Z
# 3     2021-09-12T15:23:17Z
# 4     2021-09-09T20:28:51Z
# 5     2021-09-09T11:08:36Z
# 6     2021-09-08T12:20:49Z
# 7     2021-09-06T15:10:29Z
# 8     2021-09-06T12:34:06Z
# 9     2021-09-05T09:37:47Z
# 10    2021-09-04T18:53:29Z
# 11    2021-09-04T11:47:53Z
# 12    2021-09-04T08:20:05Z
# 13    2021-09-03T20:27:41Z
# 14    2021-09-02T13:00:38Z
# 15    2021-09-02T05:36:48Z
# 16    2021-09-01T17:21:40Z
# 17    2021-09-01T16:59:59Z
# 18    2021-09-01T16:47:38Z
# 19    2021-09-01T16:43:55Z
# 20    2021-08-31T20:54:29Z
# 21    2021-08-31T12:27:13Z
# 22    2021-08-31T11:54:24Z
# 23    2021-08-30T21:54:33Z
# 24    2021-08-30T19:35:00Z
# 25    2021-08-30T14:41:49Z
# 26    2021-08-30T09:33:36Z
# 27    2021-08-29T19:45:52Z
# 28    2021-08-29T19:21:01Z
# 29    2021-08-29T07:46:49Z
# 30    2021-08-28T20:58:38Z
# 31    2021-08-28T20:52:22Z
# 32    2021-08-27T16:37:41Z
# 33    2021-08-26T18:57:16Z
# ...

# %%
df["date"] = pd.to_datetime(df["Publish Times in ISO-8601"])
df.date
# Out:
# 0    2021-09-15 10:46:49+00:00
# 1    2021-09-13 08:43:47+00:00
# 2    2021-09-12 18:04:40+00:00
# 3    2021-09-12 15:23:17+00:00
# 4    2021-09-09 20:28:51+00:00
# 5    2021-09-09 11:08:36+00:00
# 6    2021-09-08 12:20:49+00:00
# 7    2021-09-06 15:10:29+00:00
# 8    2021-09-06 12:34:06+00:00
# 9    2021-09-05 09:37:47+00:00
# 10   2021-09-04 18:53:29+00:00
# 11   2021-09-04 11:47:53+00:00
# 12   2021-09-04 08:20:05+00:00
# 13   2021-09-03 20:27:41+00:00
# 14   2021-09-02 13:00:38+00:00
# 15   2021-09-02 05:36:48+00:00
# 16   2021-09-01 17:21:40+00:00
# 17   2021-09-01 16:59:59+00:00
# 18   2021-09-01 16:47:38+00:00
# 19   2021-09-01 16:43:55+00:00
# 20   2021-08-31 20:54:29+00:00
# 21   2021-08-31 12:27:13+00:00
# 22   2021-08-31 11:54:24+00:00
# 23   2021-08-30 21:54:33+00:00
# 24   2021-08-30 19:35:00+00:00
# 25   2021-08-30 14:41:49+00:00
# 26   2021-08-30 09:33:36+00:00
# 27   2021-08-29 19:45:52+00:00
# 28   2021-08-29 19:21:01+00:00
# 29   2021-08-29 07:46:49+00:00
# ...

# %%
df.date.dt.hour
# Out:
# 0     10
# 1      8
# 2     18
# 3     15
# 4     20
# 5     11
# 6     12
# 7     15
# 8     12
# 9      9
# 10    18
# 11    11
# 12     8
# 13    20
# 14    13
# 15     5
# 16    17
# 17    16
# 18    16
# 19    16
# 20    20
# 21    12
# 22    11
# 23    21
# 24    19
# 25    14
# 26     9
# 27    19
# 28    19
# 29     7
# 30    20
# 31    20
# 32    16
# 33    18
# 34    18
# 35    13
# 36    13
# 37    10
# 38    20
# 39    17
# 40     8
# 41     6
# 42     6
# 43    21
# 44     9
# 45    22
# 46    22
# Name: date, dtype: int64

# %%
df["upload_count"] = df.index + 1

# %%
df.upload_count = df.upload_count.to_list()[::-1]

# %%
df.head()
# Out:
#                                         Video Titles Descriptions  \
# 0  Taliban at Georgopol PUBG.  49 containers full...      NO DATA
# 1  Taliban caught 6.5 Million dollars in Amrullah...      NO DATA
# 2  Womens protest in Nangrahar for the support of...      NO DATA
# 3  Qatar Foreign Minister meet with IEA Leaders a...      NO DATA
# 4                                 IEA Military force      NO DATA
#
#                                    Thumbnail URLs  \
# 0  https://i.ytimg.com/vi/WCJA3SoayCc/default.jpg
# 1  https://i.ytimg.com/vi/k96gBGUbzzk/default.jpg
# 2  https://i.ytimg.com/vi/wNypwm7aaQc/default.jpg
# 3  https://i.ytimg.com/vi/Yt42vB98wAI/default.jpg
# 4  https://i.ytimg.com/vi/nggrzPl3ePQ/default.jpg
#
#                                     Video URLs Publish Times in ISO-8601  \
# 0  https://www.youtube.com/watch?v=WCJA3SoayCc      2021-09-15T10:46:49Z
# 1  https://www.youtube.com/watch?v=k96gBGUbzzk      2021-09-13T08:43:47Z
# ...

# %%
df.index = df.date

# %%
df.upload_count.plot()
plt.style.use("fivethirtyeight")
plt.ylabel("Total Videos Uploaded");

# %%
videos_with_taliban_in_title = df.loc[df["Video Titles"].str.contains("Taliban|taliban") == True]
videos_with_taliban_in_title
# Out:
#                                                                 Video Titles  \
# date
# 2021-09-15 10:46:49+00:00  Taliban at Georgopol PUBG.  49 containers full...
# 2021-09-13 08:43:47+00:00  Taliban caught 6.5 Million dollars in Amrullah...
# 2021-09-09 11:08:36+00:00  Taliban got 100000 $ from Amrullah Saleh House...
# 2021-09-05 09:37:47+00:00          Panjsher Airport Under control of Taliban
# 2021-09-04 18:53:29+00:00  New kind of weapons caught by Taliban in Panjsher
# 2021-09-04 11:47:53+00:00  The Panjsher terrorists have been Arested by T...
# 2021-09-04 08:20:05+00:00       Kandahar Taliban Celebrating Independent Day
# 2021-09-03 20:27:41+00:00          That Military Veichels of US with Taliban
# 2021-09-01 16:59:59+00:00        Taliban with their heavy Military Vicheles.
# 2021-08-30 09:33:36+00:00         Womens Education under Controll of Taliban
# 2021-08-24 06:50:47+00:00        Kabul Municipality Under Control of Taliban
#
# ...

# %% [markdown]
# # Create wordcloud from Lovelace comments for Mr. Malang
#
# 1. Get all the comments data from Lovelace
# 2. Combine all of the comment text into one big string.
# 4. Paste it to [this](https://www.jasondavies.com/wordcloud/) site
#
# ## Challenge
#
# Try and install this library and use it to generate your own wordlcoud https://pypi.org/project/stylecloud/
